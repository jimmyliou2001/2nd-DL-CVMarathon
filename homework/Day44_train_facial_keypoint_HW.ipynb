# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
import tensorflow as tf
print(tf.__version__)

import os
from google.colab import drive 
drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 
# 可以自己改路徑
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.
# 1.15.2
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /content/gdrive/My Drive
# /content/gdrive/My Drive/cupoy_cv_part4

# %%
# %cd cupoy_cv_part4
# Out:
# /content/gdrive/My Drive/cupoy_cv_part4

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
# 印出網路結構
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0085 - val_loss: 0.0027
#
# Epoch 00001: val_loss improved from inf to 0.00267, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0021 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00267 to 0.00192, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0014 - val_loss: 0.0019
#
# Epoch 00003: val_loss did not improve from 0.00192
# Epoch 4/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00004: val_loss improved from 0.00192 to 0.00190, saving model to best_weights.h5
# Epoch 5/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00005: val_loss improved from 0.00190 to 0.00182, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0010 - val_loss: 0.0018
#
# Epoch 00006: val_loss improved from 0.00182 to 0.00181, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.1890e-04 - val_loss: 0.0017
#
# Epoch 00007: val_loss improved from 0.00181 to 0.00166, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.1874e-04 - val_loss: 0.0015
#
# Epoch 00008: val_loss improved from 0.00166 to 0.00154, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 7.3041e-04 - val_loss: 0.0014
#
# Epoch 00009: val_loss improved from 0.00154 to 0.00140, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 6.4217e-04 - val_loss: 0.0012
#
# Epoch 00010: val_loss improved from 0.00140 to 0.00125, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 5.8533e-04 - val_loss: 0.0012
#
# Epoch 00011: val_loss improved from 0.00125 to 0.00119, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 5.3302e-04 - val_loss: 0.0011
#
# Epoch 00012: val_loss improved from 0.00119 to 0.00110, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.9861e-04 - val_loss: 0.0010
#
# Epoch 00013: val_loss improved from 0.00110 to 0.00105, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.7624e-04 - val_loss: 9.9769e-04
#
# Epoch 00014: val_loss improved from 0.00105 to 0.00100, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.4063e-04 - val_loss: 9.8580e-04
#
# Epoch 00015: val_loss improved from 0.00100 to 0.00099, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.1124e-04 - val_loss: 9.5868e-04
#
# Epoch 00016: val_loss improved from 0.00099 to 0.00096, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.0398e-04 - val_loss: 9.6802e-04
#
# Epoch 00017: val_loss did not improve from 0.00096
# Epoch 18/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.7596e-04 - val_loss: 9.3967e-04
#
# Epoch 00018: val_loss improved from 0.00096 to 0.00094, saving model to best_weights.h5
# Epoch 19/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.6684e-04 - val_loss: 9.0966e-04
#
# Epoch 00019: val_loss improved from 0.00094 to 0.00091, saving model to best_weights.h5
# Epoch 20/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.5464e-04 - val_loss: 9.1413e-04
#
# Epoch 00020: val_loss did not improve from 0.00091
# Epoch 21/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.4173e-04 - val_loss: 9.0257e-04
#
# Epoch 00021: val_loss improved from 0.00091 to 0.00090, saving model to best_weights.h5
# Epoch 22/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.2761e-04 - val_loss: 8.5194e-04
#
# Epoch 00022: val_loss improved from 0.00090 to 0.00085, saving model to best_weights.h5
# Epoch 23/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.2482e-04 - val_loss: 8.6388e-04
#
# Epoch 00023: val_loss did not improve from 0.00085
# Epoch 24/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.0539e-04 - val_loss: 8.4560e-04
#
# Epoch 00024: val_loss improved from 0.00085 to 0.00085, saving model to best_weights.h5
# Epoch 25/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.0243e-04 - val_loss: 8.4259e-04
#
# Epoch 00025: val_loss improved from 0.00085 to 0.00084, saving model to best_weights.h5
# Epoch 26/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.9761e-04 - val_loss: 8.6690e-04
#
# Epoch 00026: val_loss did not improve from 0.00084
# Epoch 27/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.8345e-04 - val_loss: 8.5228e-04
#
# Epoch 00027: val_loss did not improve from 0.00084
# Epoch 28/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.8362e-04 - val_loss: 8.3768e-04
#
# Epoch 00028: val_loss improved from 0.00084 to 0.00084, saving model to best_weights.h5
# Epoch 29/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.8327e-04 - val_loss: 8.2716e-04
#
# Epoch 00029: val_loss improved from 0.00084 to 0.00083, saving model to best_weights.h5
# Epoch 30/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.6552e-04 - val_loss: 8.5812e-04
#
# Epoch 00030: val_loss did not improve from 0.00083
# Epoch 31/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.6433e-04 - val_loss: 8.4508e-04
#
# Epoch 00031: val_loss did not improve from 0.00083
# Epoch 32/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.5976e-04 - val_loss: 9.0408e-04
#
# Epoch 00032: val_loss did not improve from 0.00083
# Epoch 33/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.5108e-04 - val_loss: 8.0777e-04
#
# Epoch 00033: val_loss improved from 0.00083 to 0.00081, saving model to best_weights.h5
# Epoch 34/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.4035e-04 - val_loss: 7.9611e-04
#
# Epoch 00034: val_loss improved from 0.00081 to 0.00080, saving model to best_weights.h5
# Epoch 35/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.3925e-04 - val_loss: 8.0458e-04
#
# Epoch 00035: val_loss did not improve from 0.00080
# Epoch 36/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.3692e-04 - val_loss: 8.1729e-04
#
# Epoch 00036: val_loss did not improve from 0.00080
# Epoch 37/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.2897e-04 - val_loss: 8.4974e-04
#
# Epoch 00037: val_loss did not improve from 0.00080
# Epoch 38/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.2921e-04 - val_loss: 7.8259e-04
#
# Epoch 00038: val_loss improved from 0.00080 to 0.00078, saving model to best_weights.h5
# Epoch 39/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.2075e-04 - val_loss: 7.8756e-04
#
# Epoch 00039: val_loss did not improve from 0.00078
# Epoch 40/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.2207e-04 - val_loss: 7.5600e-04
#
# Epoch 00040: val_loss improved from 0.00078 to 0.00076, saving model to best_weights.h5
# Epoch 41/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.1869e-04 - val_loss: 7.7008e-04
#
# Epoch 00041: val_loss did not improve from 0.00076
# Epoch 42/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.1293e-04 - val_loss: 7.9969e-04
#
# Epoch 00042: val_loss did not improve from 0.00076
# Epoch 43/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.0593e-04 - val_loss: 7.7682e-04
#
# Epoch 00043: val_loss did not improve from 0.00076
# Epoch 44/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.0700e-04 - val_loss: 7.5501e-04
#
# Epoch 00044: val_loss improved from 0.00076 to 0.00076, saving model to best_weights.h5
# Epoch 45/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.0822e-04 - val_loss: 7.7312e-04
#
# Epoch 00045: val_loss did not improve from 0.00076
# Epoch 46/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9938e-04 - val_loss: 7.5462e-04
#
# Epoch 00046: val_loss improved from 0.00076 to 0.00075, saving model to best_weights.h5
# Epoch 47/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9448e-04 - val_loss: 7.6200e-04
#
# Epoch 00047: val_loss did not improve from 0.00075
# Epoch 48/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9456e-04 - val_loss: 7.6158e-04
#
# Epoch 00048: val_loss did not improve from 0.00075
# Epoch 49/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9347e-04 - val_loss: 7.8119e-04
#
# Epoch 00049: val_loss did not improve from 0.00075
# Epoch 50/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9635e-04 - val_loss: 7.6967e-04
#
# Epoch 00050: val_loss did not improve from 0.00075
# Epoch 51/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8939e-04 - val_loss: 7.8555e-04
#
# Epoch 00051: val_loss did not improve from 0.00075
# Epoch 52/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9119e-04 - val_loss: 7.5933e-04
#
# Epoch 00052: val_loss did not improve from 0.00075
# Epoch 53/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8843e-04 - val_loss: 7.7675e-04
#
# Epoch 00053: val_loss did not improve from 0.00075
# Epoch 54/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8359e-04 - val_loss: 7.5932e-04
#
# Epoch 00054: val_loss did not improve from 0.00075
# Epoch 55/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8121e-04 - val_loss: 7.4762e-04
#
# Epoch 00055: val_loss improved from 0.00075 to 0.00075, saving model to best_weights.h5
# Epoch 56/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7960e-04 - val_loss: 7.7135e-04
#
# Epoch 00056: val_loss did not improve from 0.00075
# Epoch 57/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7181e-04 - val_loss: 7.4437e-04
#
# Epoch 00057: val_loss improved from 0.00075 to 0.00074, saving model to best_weights.h5
# Epoch 58/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7206e-04 - val_loss: 7.4775e-04
#
# Epoch 00058: val_loss did not improve from 0.00074
# Epoch 59/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7507e-04 - val_loss: 7.4389e-04
#
# Epoch 00059: val_loss improved from 0.00074 to 0.00074, saving model to best_weights.h5
# Epoch 60/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7307e-04 - val_loss: 7.4807e-04
#
# Epoch 00060: val_loss did not improve from 0.00074
# Epoch 61/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7374e-04 - val_loss: 7.3954e-04
#
# Epoch 00061: val_loss improved from 0.00074 to 0.00074, saving model to best_weights.h5
# Epoch 62/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6908e-04 - val_loss: 7.4654e-04
#
# Epoch 00062: val_loss did not improve from 0.00074
# Epoch 63/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6685e-04 - val_loss: 7.2381e-04
#
# Epoch 00063: val_loss improved from 0.00074 to 0.00072, saving model to best_weights.h5
# Epoch 64/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7084e-04 - val_loss: 7.3550e-04
#
# Epoch 00064: val_loss did not improve from 0.00072
# Epoch 65/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6645e-04 - val_loss: 7.4787e-04
#
# Epoch 00065: val_loss did not improve from 0.00072
# Epoch 66/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6630e-04 - val_loss: 7.6910e-04
#
# Epoch 00066: val_loss did not improve from 0.00072
# Epoch 67/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6093e-04 - val_loss: 7.5546e-04
#
# Epoch 00067: val_loss did not improve from 0.00072
# Epoch 68/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5658e-04 - val_loss: 7.6521e-04
#
# Epoch 00068: val_loss did not improve from 0.00072
# Epoch 69/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5919e-04 - val_loss: 7.4550e-04
#
# Epoch 00069: val_loss did not improve from 0.00072
# Epoch 70/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5828e-04 - val_loss: 7.5463e-04
#
# Epoch 00070: val_loss did not improve from 0.00072
# Epoch 71/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5615e-04 - val_loss: 7.5244e-04
#
# Epoch 00071: val_loss did not improve from 0.00072
# Epoch 72/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5022e-04 - val_loss: 7.6886e-04
#
# Epoch 00072: val_loss did not improve from 0.00072
# Epoch 73/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5130e-04 - val_loss: 7.5109e-04
#
# Epoch 00073: val_loss did not improve from 0.00072
# Epoch 74/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5179e-04 - val_loss: 7.6305e-04
#
# Epoch 00074: val_loss did not improve from 0.00072
# Epoch 75/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4912e-04 - val_loss: 7.6548e-04
#
# Epoch 00075: val_loss did not improve from 0.00072
# Epoch 76/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4578e-04 - val_loss: 7.5248e-04
#
# Epoch 00076: val_loss did not improve from 0.00072
# Epoch 77/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4490e-04 - val_loss: 7.4820e-04
#
# Epoch 00077: val_loss did not improve from 0.00072
# Epoch 78/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4442e-04 - val_loss: 7.4387e-04
#
# Epoch 00078: val_loss did not improve from 0.00072
# Epoch 79/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4141e-04 - val_loss: 7.4270e-04
#
# Epoch 00079: val_loss did not improve from 0.00072
# Epoch 80/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4320e-04 - val_loss: 7.7153e-04
#
# Epoch 00080: val_loss did not improve from 0.00072
# Epoch 81/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3861e-04 - val_loss: 7.4679e-04
#
# Epoch 00081: val_loss did not improve from 0.00072
# Epoch 82/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3968e-04 - val_loss: 7.6957e-04
#
# Epoch 00082: val_loss did not improve from 0.00072
# Epoch 83/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3672e-04 - val_loss: 7.1357e-04
#
# Epoch 00083: val_loss improved from 0.00072 to 0.00071, saving model to best_weights.h5
# Epoch 84/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3887e-04 - val_loss: 7.2913e-04
#
# Epoch 00084: val_loss did not improve from 0.00071
# Epoch 85/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3404e-04 - val_loss: 7.6810e-04
#
# Epoch 00085: val_loss did not improve from 0.00071
# Epoch 86/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3247e-04 - val_loss: 7.4297e-04
#
# Epoch 00086: val_loss did not improve from 0.00071
# Epoch 87/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3388e-04 - val_loss: 7.4474e-04
#
# Epoch 00087: val_loss did not improve from 0.00071
# Epoch 88/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3549e-04 - val_loss: 7.2821e-04
#
# Epoch 00088: val_loss did not improve from 0.00071
# Epoch 89/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3040e-04 - val_loss: 7.2546e-04
#
# Epoch 00089: val_loss did not improve from 0.00071
# Epoch 90/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3013e-04 - val_loss: 7.3554e-04
#
# Epoch 00090: val_loss did not improve from 0.00071
# Epoch 91/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2868e-04 - val_loss: 7.8389e-04
#
# Epoch 00091: val_loss did not improve from 0.00071
# Epoch 92/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2733e-04 - val_loss: 7.3242e-04
#
# Epoch 00092: val_loss did not improve from 0.00071
# Epoch 93/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3460e-04 - val_loss: 7.5110e-04
#
# Epoch 00093: val_loss did not improve from 0.00071
# Epoch 94/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2790e-04 - val_loss: 7.2869e-04
#
# Epoch 00094: val_loss did not improve from 0.00071
# Epoch 95/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2496e-04 - val_loss: 7.5069e-04
#
# Epoch 00095: val_loss did not improve from 0.00071
# Epoch 96/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2377e-04 - val_loss: 7.5519e-04
#
# Epoch 00096: val_loss did not improve from 0.00071
# Epoch 97/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2409e-04 - val_loss: 7.4792e-04
#
# Epoch 00097: val_loss did not improve from 0.00071
# Epoch 98/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2193e-04 - val_loss: 7.2079e-04
#
# Epoch 00098: val_loss did not improve from 0.00071
# Epoch 99/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1989e-04 - val_loss: 7.5290e-04
#
# Epoch 00099: val_loss did not improve from 0.00071
# Epoch 100/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2124e-04 - val_loss: 7.5826e-04
#
# Epoch 00100: val_loss did not improve from 0.00071
# Epoch 101/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2489e-04 - val_loss: 7.4349e-04
#
# Epoch 00101: val_loss did not improve from 0.00071
# Epoch 102/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2004e-04 - val_loss: 7.5776e-04
#
# Epoch 00102: val_loss did not improve from 0.00071
# Epoch 103/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2024e-04 - val_loss: 7.4966e-04
#
# Epoch 00103: val_loss did not improve from 0.00071
# Epoch 104/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1950e-04 - val_loss: 7.2755e-04
#
# Epoch 00104: val_loss did not improve from 0.00071
# Epoch 105/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1970e-04 - val_loss: 7.6580e-04
#
# Epoch 00105: val_loss did not improve from 0.00071
# Epoch 106/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1438e-04 - val_loss: 7.5058e-04
#
# Epoch 00106: val_loss did not improve from 0.00071
# Epoch 107/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1708e-04 - val_loss: 7.2941e-04
#
# Epoch 00107: val_loss did not improve from 0.00071
# Epoch 108/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1481e-04 - val_loss: 7.3115e-04
#
# Epoch 00108: val_loss did not improve from 0.00071
# Epoch 109/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1274e-04 - val_loss: 7.2836e-04
#
# Epoch 00109: val_loss did not improve from 0.00071
# Epoch 110/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1431e-04 - val_loss: 7.4846e-04
#
# Epoch 00110: val_loss did not improve from 0.00071
# Epoch 111/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1857e-04 - val_loss: 7.5531e-04
#
# Epoch 00111: val_loss did not improve from 0.00071
# Epoch 112/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1577e-04 - val_loss: 7.4357e-04
#
# Epoch 00112: val_loss did not improve from 0.00071
# Epoch 113/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1235e-04 - val_loss: 7.3611e-04
#
# Epoch 00113: val_loss did not improve from 0.00071
# Epoch 114/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0946e-04 - val_loss: 7.4916e-04
#
# Epoch 00114: val_loss did not improve from 0.00071
# Epoch 115/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1022e-04 - val_loss: 7.5445e-04
#
# Epoch 00115: val_loss did not improve from 0.00071
# Epoch 116/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0593e-04 - val_loss: 7.2151e-04
#
# Epoch 00116: val_loss did not improve from 0.00071
# Epoch 117/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0810e-04 - val_loss: 7.6240e-04
#
# Epoch 00117: val_loss did not improve from 0.00071
# Epoch 118/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0723e-04 - val_loss: 7.2941e-04
#
# Epoch 00118: val_loss did not improve from 0.00071
# Epoch 119/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0619e-04 - val_loss: 7.3220e-04
#
# Epoch 00119: val_loss did not improve from 0.00071
# Epoch 120/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0468e-04 - val_loss: 7.5018e-04
#
# Epoch 00120: val_loss did not improve from 0.00071
# Epoch 121/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0544e-04 - val_loss: 7.5913e-04
#
# Epoch 00121: val_loss did not improve from 0.00071
# Epoch 122/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0489e-04 - val_loss: 7.5473e-04
#
# Epoch 00122: val_loss did not improve from 0.00071
# Epoch 123/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0343e-04 - val_loss: 7.4167e-04
#
# Epoch 00123: val_loss did not improve from 0.00071
# Epoch 124/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0090e-04 - val_loss: 7.3705e-04
#
# Epoch 00124: val_loss did not improve from 0.00071
# Epoch 125/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0042e-04 - val_loss: 7.7574e-04
#
# Epoch 00125: val_loss did not improve from 0.00071
# Epoch 126/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0237e-04 - val_loss: 7.7010e-04
#
# Epoch 00126: val_loss did not improve from 0.00071
# Epoch 127/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0284e-04 - val_loss: 7.3108e-04
#
# Epoch 00127: val_loss did not improve from 0.00071
# Epoch 128/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0277e-04 - val_loss: 7.3540e-04
#
# Epoch 00128: val_loss did not improve from 0.00071
# Epoch 129/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.8822e-05 - val_loss: 7.5145e-04
#
# Epoch 00129: val_loss did not improve from 0.00071
# Epoch 130/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0064e-04 - val_loss: 7.3945e-04
#
# Epoch 00130: val_loss did not improve from 0.00071
# Epoch 131/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.8210e-05 - val_loss: 7.4545e-04
#
# Epoch 00131: val_loss did not improve from 0.00071
# Epoch 132/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.9704e-05 - val_loss: 7.3683e-04
#
# Epoch 00132: val_loss did not improve from 0.00071
# Epoch 133/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.6978e-05 - val_loss: 7.6074e-04
#
# Epoch 00133: val_loss did not improve from 0.00071
# Epoch 134/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.8460e-05 - val_loss: 7.7804e-04
#
# Epoch 00134: val_loss did not improve from 0.00071
# Epoch 135/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0001e-04 - val_loss: 7.4352e-04
#
# Epoch 00135: val_loss did not improve from 0.00071
# Epoch 136/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.8282e-05 - val_loss: 7.4096e-04
#
# Epoch 00136: val_loss did not improve from 0.00071
# Epoch 137/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.6757e-05 - val_loss: 7.3219e-04
#
# Epoch 00137: val_loss did not improve from 0.00071
# Epoch 138/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.7838e-05 - val_loss: 7.4053e-04
#
# Epoch 00138: val_loss did not improve from 0.00071
# Epoch 139/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.4410e-05 - val_loss: 7.6618e-04
#
# Epoch 00139: val_loss did not improve from 0.00071
# Epoch 140/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.6098e-05 - val_loss: 7.2941e-04
#
# Epoch 00140: val_loss did not improve from 0.00071
# Epoch 141/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.4185e-05 - val_loss: 7.6142e-04
#
# Epoch 00141: val_loss did not improve from 0.00071
# Epoch 142/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.3633e-05 - val_loss: 7.5100e-04
#
# Epoch 00142: val_loss did not improve from 0.00071
# Epoch 143/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.3616e-05 - val_loss: 7.2913e-04
#
# Epoch 00143: val_loss did not improve from 0.00071
# Epoch 144/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.2565e-05 - val_loss: 7.3908e-04
#
# Epoch 00144: val_loss did not improve from 0.00071
# Epoch 145/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.0629e-05 - val_loss: 7.5271e-04
#
# Epoch 00145: val_loss did not improve from 0.00071
# Epoch 146/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.2166e-05 - val_loss: 7.7235e-04
#
# Epoch 00146: val_loss did not improve from 0.00071
# Epoch 147/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.0723e-05 - val_loss: 7.3340e-04
#
# Epoch 00147: val_loss did not improve from 0.00071
# Epoch 148/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.1257e-05 - val_loss: 7.4954e-04
#
# Epoch 00148: val_loss did not improve from 0.00071
# Epoch 149/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.0164e-05 - val_loss: 7.3683e-04
#
# Epoch 00149: val_loss did not improve from 0.00071
# Epoch 150/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.9115e-05 - val_loss: 7.3988e-04
#
# Epoch 00150: val_loss did not improve from 0.00071

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Your code

# %%
# 實現圖片以及關機點 label 做左右翻轉的函數
def augment_data(img, points):
    rows, cols = img.shape
    new_img = np.copy(img)
    
    # 翻轉圖片
    for i in range(96):
        for j in range(48):
            temp = img[i][j]
            new_img[i][j] = img[i][cols-j-1]
            new_img[i][cols-j-1] = temp
            
    # 翻轉關鍵點 label
    new_points = np.copy(points)
    for i in range(0,30,2):
        new_points[i] = -points[i]
    
    # 調整對稱的 label
    new_points_temp = np.copy(new_points)
    new_points[0:2] = new_points_temp[2:4]
    new_points[2:4] = new_points_temp[0:2]
    new_points[4:6] = new_points_temp[8:10]
    new_points[6:8] = new_points_temp[10:12]
    new_points[8:10] = new_points_temp[4:6]
    new_points[10:12] = new_points_temp[6:8]
    new_points[12:14] = new_points_temp[16:18]
    new_points[14:16] = new_points_temp[18:20]
    new_points[16:18] = new_points_temp[12:14]
    new_points[18:20] = new_points_temp[14:16]
    new_points[22:24] = new_points_temp[24:26]
    new_points[24:26] = new_points_temp[22:24]
        
    return new_img, new_points

# %%
flip_img, flip_points = augment_data(imgs_train[0], points_train[0])

fig = plt.figure()
ax = fig.add_subplot(1, 2, 1, xticks=[], yticks=[])
plot_keypoints(imgs_train[0], points_train[0]) # 原來的圖片
ax = fig.add_subplot(1, 2, 2, xticks=[], yticks=[])
plot_keypoints(flip_img, flip_points) # 翻轉後的圖片

# %%
# 創建 list
aug_imgs_train = []
aug_points_train = []

# 對所有原始資料做 augmentation
for i in range(imgs_train.shape[0]):
    # 做左右翻轉
    aug_img, aug_point = augment_data(imgs_train[i], points_train[i])
    
    # append 原始資料
    aug_imgs_train.append(imgs_train[i])
    aug_points_train.append(points_train[i]) 
    
    # append 做過 augmentation 後的資料
    aug_imgs_train.append(aug_img)
    aug_points_train.append(aug_point) 

# convert to numpy
aug_imgs_train = np.array(aug_imgs_train)   
aug_points_train = np.copy(aug_points_train)

print(aug_imgs_train.shape)
print(aug_points_train.shape)
# Out:
# (4280, 96, 96)
# (4280, 30)

# %%
# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
# training the model
hist_model_aug = model_with_augment.fit(aug_imgs_train.reshape(aug_imgs_train.shape[0], 96, 96, 1), aug_points_train, 
                           validation_split=0.2, batch_size=64, callbacks=[checkpoint_aug, hist],
                           shuffle=True, epochs=150, verbose=1)
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/150
# 3424/3424 [==============================] - 30s 9ms/step - loss: 0.0050 - val_loss: 0.0019
#
# Epoch 00001: val_loss improved from inf to 0.00186, saving model to best_weights_augment.h5
# Epoch 2/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00002: val_loss did not improve from 0.00186
# Epoch 3/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 0.0011 - val_loss: 0.0019
#
# Epoch 00003: val_loss did not improve from 0.00186
# Epoch 4/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 9.9922e-04 - val_loss: 0.0017
#
# Epoch 00004: val_loss improved from 0.00186 to 0.00168, saving model to best_weights_augment.h5
# Epoch 5/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 8.2996e-04 - val_loss: 0.0015
#
# Epoch 00005: val_loss improved from 0.00168 to 0.00150, saving model to best_weights_augment.h5
# Epoch 6/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 6.4606e-04 - val_loss: 0.0012
#
# Epoch 00006: val_loss improved from 0.00150 to 0.00121, saving model to best_weights_augment.h5
# Epoch 7/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 5.5061e-04 - val_loss: 0.0011
#
# Epoch 00007: val_loss improved from 0.00121 to 0.00109, saving model to best_weights_augment.h5
# Epoch 8/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 4.8871e-04 - val_loss: 0.0010
#
# Epoch 00008: val_loss improved from 0.00109 to 0.00101, saving model to best_weights_augment.h5
# Epoch 9/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 4.4802e-04 - val_loss: 9.2189e-04
#
# Epoch 00009: val_loss improved from 0.00101 to 0.00092, saving model to best_weights_augment.h5
# Epoch 10/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 4.2234e-04 - val_loss: 8.8092e-04
#
# Epoch 00010: val_loss improved from 0.00092 to 0.00088, saving model to best_weights_augment.h5
# Epoch 11/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 3.8254e-04 - val_loss: 8.2283e-04
#
# Epoch 00011: val_loss improved from 0.00088 to 0.00082, saving model to best_weights_augment.h5
# Epoch 12/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 3.6719e-04 - val_loss: 8.2301e-04
#
# Epoch 00012: val_loss did not improve from 0.00082
# Epoch 13/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 3.4756e-04 - val_loss: 7.5874e-04
#
# Epoch 00013: val_loss improved from 0.00082 to 0.00076, saving model to best_weights_augment.h5
# Epoch 14/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 3.2625e-04 - val_loss: 7.6318e-04
#
# Epoch 00014: val_loss did not improve from 0.00076
# Epoch 15/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 3.1809e-04 - val_loss: 8.2433e-04
#
# Epoch 00015: val_loss did not improve from 0.00076
# Epoch 16/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 3.1115e-04 - val_loss: 7.9695e-04
#
# Epoch 00016: val_loss did not improve from 0.00076
# Epoch 17/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.9866e-04 - val_loss: 6.9923e-04
#
# Epoch 00017: val_loss improved from 0.00076 to 0.00070, saving model to best_weights_augment.h5
# Epoch 18/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.8521e-04 - val_loss: 7.4126e-04
#
# Epoch 00018: val_loss did not improve from 0.00070
# Epoch 19/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.8485e-04 - val_loss: 7.1238e-04
#
# Epoch 00019: val_loss did not improve from 0.00070
# Epoch 20/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.6815e-04 - val_loss: 6.8925e-04
#
# Epoch 00020: val_loss improved from 0.00070 to 0.00069, saving model to best_weights_augment.h5
# Epoch 21/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.6063e-04 - val_loss: 6.7999e-04
#
# Epoch 00021: val_loss improved from 0.00069 to 0.00068, saving model to best_weights_augment.h5
# Epoch 22/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.5211e-04 - val_loss: 6.9420e-04
#
# Epoch 00022: val_loss did not improve from 0.00068
# Epoch 23/150
# 3424/3424 [==============================] - 31s 9ms/step - loss: 2.5141e-04 - val_loss: 7.1035e-04
#
# Epoch 00023: val_loss did not improve from 0.00068
# Epoch 24/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.4214e-04 - val_loss: 7.0256e-04
#
# Epoch 00024: val_loss did not improve from 0.00068
# Epoch 25/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.4025e-04 - val_loss: 6.6671e-04
#
# Epoch 00025: val_loss improved from 0.00068 to 0.00067, saving model to best_weights_augment.h5
# Epoch 26/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.2916e-04 - val_loss: 6.3768e-04
#
# Epoch 00026: val_loss improved from 0.00067 to 0.00064, saving model to best_weights_augment.h5
# Epoch 27/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.2644e-04 - val_loss: 6.7358e-04
#
# Epoch 00027: val_loss did not improve from 0.00064
# Epoch 28/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.2266e-04 - val_loss: 6.3656e-04
#
# Epoch 00028: val_loss improved from 0.00064 to 0.00064, saving model to best_weights_augment.h5
# Epoch 29/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.1481e-04 - val_loss: 6.6057e-04
#
# Epoch 00029: val_loss did not improve from 0.00064
# Epoch 30/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.1206e-04 - val_loss: 6.4865e-04
#
# Epoch 00030: val_loss did not improve from 0.00064
# Epoch 31/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.0593e-04 - val_loss: 6.5912e-04
#
# Epoch 00031: val_loss did not improve from 0.00064
# Epoch 32/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.9842e-04 - val_loss: 6.2906e-04
#
# Epoch 00032: val_loss improved from 0.00064 to 0.00063, saving model to best_weights_augment.h5
# Epoch 33/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.9711e-04 - val_loss: 6.2978e-04
#
# Epoch 00033: val_loss did not improve from 0.00063
# Epoch 34/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.9603e-04 - val_loss: 6.4113e-04
#
# Epoch 00034: val_loss did not improve from 0.00063
# Epoch 35/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.9195e-04 - val_loss: 6.4421e-04
#
# Epoch 00035: val_loss did not improve from 0.00063
# Epoch 36/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.8519e-04 - val_loss: 6.4277e-04
#
# Epoch 00036: val_loss did not improve from 0.00063
# Epoch 37/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.8369e-04 - val_loss: 6.4018e-04
#
# Epoch 00037: val_loss did not improve from 0.00063
# Epoch 38/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.8236e-04 - val_loss: 6.2772e-04
#
# Epoch 00038: val_loss improved from 0.00063 to 0.00063, saving model to best_weights_augment.h5
# Epoch 39/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.8031e-04 - val_loss: 6.3136e-04
#
# Epoch 00039: val_loss did not improve from 0.00063
# Epoch 40/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.7605e-04 - val_loss: 6.2367e-04
#
# Epoch 00040: val_loss improved from 0.00063 to 0.00062, saving model to best_weights_augment.h5
# Epoch 41/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.7310e-04 - val_loss: 6.1312e-04
#
# Epoch 00041: val_loss improved from 0.00062 to 0.00061, saving model to best_weights_augment.h5
# Epoch 42/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.7315e-04 - val_loss: 6.7490e-04
#
# Epoch 00042: val_loss did not improve from 0.00061
# Epoch 43/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.6795e-04 - val_loss: 6.4356e-04
#
# Epoch 00043: val_loss did not improve from 0.00061
# Epoch 44/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.6366e-04 - val_loss: 6.3662e-04
#
# Epoch 00044: val_loss did not improve from 0.00061
# Epoch 45/150
# 3424/3424 [==============================] - 31s 9ms/step - loss: 1.6314e-04 - val_loss: 6.3213e-04
#
# Epoch 00045: val_loss did not improve from 0.00061
# Epoch 46/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.5908e-04 - val_loss: 6.3988e-04
#
# Epoch 00046: val_loss did not improve from 0.00061
# Epoch 47/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.5864e-04 - val_loss: 6.1620e-04
#
# Epoch 00047: val_loss did not improve from 0.00061
# Epoch 48/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.5687e-04 - val_loss: 6.2418e-04
#
# Epoch 00048: val_loss did not improve from 0.00061
# Epoch 49/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.5298e-04 - val_loss: 6.4219e-04
#
# Epoch 00049: val_loss did not improve from 0.00061
# Epoch 50/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.5043e-04 - val_loss: 6.2913e-04
#
# Epoch 00050: val_loss did not improve from 0.00061
# Epoch 51/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.5288e-04 - val_loss: 6.1928e-04
#
# Epoch 00051: val_loss did not improve from 0.00061
# Epoch 52/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.5000e-04 - val_loss: 6.1220e-04
#
# Epoch 00052: val_loss improved from 0.00061 to 0.00061, saving model to best_weights_augment.h5
# Epoch 53/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.4462e-04 - val_loss: 6.2539e-04
#
# Epoch 00053: val_loss did not improve from 0.00061
# Epoch 54/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.4382e-04 - val_loss: 6.0840e-04
#
# Epoch 00054: val_loss improved from 0.00061 to 0.00061, saving model to best_weights_augment.h5
# Epoch 55/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.4580e-04 - val_loss: 6.3136e-04
#
# Epoch 00055: val_loss did not improve from 0.00061
# Epoch 56/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.3911e-04 - val_loss: 6.2293e-04
#
# Epoch 00056: val_loss did not improve from 0.00061
# Epoch 57/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.3847e-04 - val_loss: 6.5129e-04
#
# Epoch 00057: val_loss did not improve from 0.00061
# Epoch 58/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.3654e-04 - val_loss: 6.5173e-04
#
# Epoch 00058: val_loss did not improve from 0.00061
# Epoch 59/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.3484e-04 - val_loss: 6.1995e-04
#
# Epoch 00059: val_loss did not improve from 0.00061
# Epoch 60/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.3257e-04 - val_loss: 6.3822e-04
#
# Epoch 00060: val_loss did not improve from 0.00061
# Epoch 61/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.3043e-04 - val_loss: 6.1106e-04
#
# Epoch 00061: val_loss did not improve from 0.00061
# Epoch 62/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.3114e-04 - val_loss: 6.0378e-04
#
# Epoch 00062: val_loss improved from 0.00061 to 0.00060, saving model to best_weights_augment.h5
# Epoch 63/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.3132e-04 - val_loss: 6.1332e-04
#
# Epoch 00063: val_loss did not improve from 0.00060
# Epoch 64/150
# 3424/3424 [==============================] - 26s 8ms/step - loss: 1.3062e-04 - val_loss: 6.0426e-04
#
# Epoch 00064: val_loss did not improve from 0.00060
# Epoch 65/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.2872e-04 - val_loss: 6.0649e-04
#
# Epoch 00065: val_loss did not improve from 0.00060
# Epoch 66/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.2586e-04 - val_loss: 6.3302e-04
#
# Epoch 00066: val_loss did not improve from 0.00060
# Epoch 67/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.2226e-04 - val_loss: 6.2508e-04
#
# Epoch 00067: val_loss did not improve from 0.00060
# Epoch 68/150
# 3424/3424 [==============================] - 30s 9ms/step - loss: 1.2474e-04 - val_loss: 6.2133e-04
#
# Epoch 00068: val_loss did not improve from 0.00060
# Epoch 69/150
# 3424/3424 [==============================] - 26s 8ms/step - loss: 1.2320e-04 - val_loss: 6.1710e-04
#
# Epoch 00069: val_loss did not improve from 0.00060
# Epoch 70/150
# 3424/3424 [==============================] - 26s 8ms/step - loss: 1.2332e-04 - val_loss: 6.5029e-04
#
# Epoch 00070: val_loss did not improve from 0.00060
# Epoch 71/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.2144e-04 - val_loss: 6.3703e-04
#
# Epoch 00071: val_loss did not improve from 0.00060
# Epoch 72/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.1935e-04 - val_loss: 6.0777e-04
#
# Epoch 00072: val_loss did not improve from 0.00060
# Epoch 73/150
# 3424/3424 [==============================] - 26s 8ms/step - loss: 1.1983e-04 - val_loss: 6.0990e-04
#
# Epoch 00073: val_loss did not improve from 0.00060
# Epoch 74/150
# 3424/3424 [==============================] - 26s 8ms/step - loss: 1.1901e-04 - val_loss: 5.9972e-04
#
# Epoch 00074: val_loss improved from 0.00060 to 0.00060, saving model to best_weights_augment.h5
# Epoch 75/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.1685e-04 - val_loss: 6.2256e-04
#
# Epoch 00075: val_loss did not improve from 0.00060
# Epoch 76/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.1654e-04 - val_loss: 6.2533e-04
#
# Epoch 00076: val_loss did not improve from 0.00060
# Epoch 77/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.1543e-04 - val_loss: 6.2240e-04
#
# Epoch 00077: val_loss did not improve from 0.00060
# Epoch 78/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.1393e-04 - val_loss: 6.2124e-04
#
# Epoch 00078: val_loss did not improve from 0.00060
# Epoch 79/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.1374e-04 - val_loss: 6.1138e-04
#
# Epoch 00079: val_loss did not improve from 0.00060
# Epoch 80/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.1549e-04 - val_loss: 6.3022e-04
#
# Epoch 00080: val_loss did not improve from 0.00060
# Epoch 81/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.0890e-04 - val_loss: 6.1529e-04
#
# Epoch 00081: val_loss did not improve from 0.00060
# Epoch 82/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.1227e-04 - val_loss: 6.1171e-04
#
# Epoch 00082: val_loss did not improve from 0.00060
# Epoch 83/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.1122e-04 - val_loss: 6.0466e-04
#
# Epoch 00083: val_loss did not improve from 0.00060
# Epoch 84/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.0879e-04 - val_loss: 6.3263e-04
#
# Epoch 00084: val_loss did not improve from 0.00060
# Epoch 85/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.0649e-04 - val_loss: 6.3976e-04
#
# Epoch 00085: val_loss did not improve from 0.00060
# Epoch 86/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.0810e-04 - val_loss: 6.1308e-04
#
# Epoch 00086: val_loss did not improve from 0.00060
# Epoch 87/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.0685e-04 - val_loss: 6.1646e-04
#
# Epoch 00087: val_loss did not improve from 0.00060
# Epoch 88/150
# 3424/3424 [==============================] - 26s 8ms/step - loss: 1.0644e-04 - val_loss: 6.1563e-04
#
# Epoch 00088: val_loss did not improve from 0.00060
# Epoch 89/150
# 3424/3424 [==============================] - 26s 7ms/step - loss: 1.0391e-04 - val_loss: 6.1685e-04
#
# Epoch 00089: val_loss did not improve from 0.00060
# Epoch 90/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.0681e-04 - val_loss: 6.1889e-04
#
# Epoch 00090: val_loss did not improve from 0.00060
# Epoch 91/150
# 3424/3424 [==============================] - 29s 8ms/step - loss: 1.0558e-04 - val_loss: 6.1836e-04
#
# Epoch 00091: val_loss did not improve from 0.00060
# Epoch 92/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 1.0408e-04 - val_loss: 6.1096e-04
#
# Epoch 00092: val_loss did not improve from 0.00060
# Epoch 93/150
# 3424/3424 [==============================] - 26s 8ms/step - loss: 1.0294e-04 - val_loss: 6.0950e-04
#
# Epoch 00093: val_loss did not improve from 0.00060
# Epoch 94/150
# 3424/3424 [==============================] - 26s 8ms/step - loss: 1.0453e-04 - val_loss: 6.4145e-04
#
# Epoch 00094: val_loss did not improve from 0.00060
# Epoch 95/150
# 3424/3424 [==============================] - 26s 7ms/step - loss: 1.0288e-04 - val_loss: 6.3584e-04
#
# Epoch 00095: val_loss did not improve from 0.00060
# Epoch 96/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 1.0154e-04 - val_loss: 6.2954e-04
#
# Epoch 00096: val_loss did not improve from 0.00060
# Epoch 97/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 1.0132e-04 - val_loss: 6.1529e-04
#
# Epoch 00097: val_loss did not improve from 0.00060
# Epoch 98/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 1.0017e-04 - val_loss: 6.1429e-04
#
# Epoch 00098: val_loss did not improve from 0.00060
# Epoch 99/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 1.0064e-04 - val_loss: 6.1077e-04
#
# Epoch 00099: val_loss did not improve from 0.00060
# Epoch 100/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 1.0170e-04 - val_loss: 6.2923e-04
#
# Epoch 00100: val_loss did not improve from 0.00060
# Epoch 101/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 9.8141e-05 - val_loss: 6.2633e-04
#
# Epoch 00101: val_loss did not improve from 0.00060
# Epoch 102/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 9.9906e-05 - val_loss: 6.1173e-04
#
# Epoch 00102: val_loss did not improve from 0.00060
# Epoch 103/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 9.9254e-05 - val_loss: 6.3740e-04
#
# Epoch 00103: val_loss did not improve from 0.00060
# Epoch 104/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 9.9206e-05 - val_loss: 6.0290e-04
#
# Epoch 00104: val_loss did not improve from 0.00060
# Epoch 105/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 9.9351e-05 - val_loss: 6.2768e-04
#
# Epoch 00105: val_loss did not improve from 0.00060
# Epoch 106/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 9.6341e-05 - val_loss: 6.3277e-04
#
# Epoch 00106: val_loss did not improve from 0.00060
# Epoch 107/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 9.5362e-05 - val_loss: 6.2683e-04
#
# Epoch 00107: val_loss did not improve from 0.00060
# Epoch 108/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 9.6622e-05 - val_loss: 6.2558e-04
#
# Epoch 00108: val_loss did not improve from 0.00060
# Epoch 109/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 9.5319e-05 - val_loss: 6.0055e-04
#
# Epoch 00109: val_loss did not improve from 0.00060
# Epoch 110/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 9.4622e-05 - val_loss: 6.2157e-04
#
# Epoch 00110: val_loss did not improve from 0.00060
# Epoch 111/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 9.3361e-05 - val_loss: 6.2040e-04
#
# Epoch 00111: val_loss did not improve from 0.00060
# Epoch 112/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 9.4182e-05 - val_loss: 6.1102e-04
#
# Epoch 00112: val_loss did not improve from 0.00060
# Epoch 113/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 9.4862e-05 - val_loss: 6.4110e-04
#
# Epoch 00113: val_loss did not improve from 0.00060
# Epoch 114/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 9.4983e-05 - val_loss: 6.1825e-04
#
# Epoch 00114: val_loss did not improve from 0.00060
# Epoch 115/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 9.2142e-05 - val_loss: 6.3162e-04
#
# Epoch 00115: val_loss did not improve from 0.00060
# Epoch 116/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 9.2630e-05 - val_loss: 5.9849e-04
#
# Epoch 00116: val_loss improved from 0.00060 to 0.00060, saving model to best_weights_augment.h5
# Epoch 117/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 9.4603e-05 - val_loss: 6.3037e-04
#
# Epoch 00117: val_loss did not improve from 0.00060
# Epoch 118/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 9.1730e-05 - val_loss: 6.1383e-04
#
# Epoch 00118: val_loss did not improve from 0.00060
# Epoch 119/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 9.3241e-05 - val_loss: 6.2165e-04
#
# Epoch 00119: val_loss did not improve from 0.00060
# Epoch 120/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 9.3456e-05 - val_loss: 6.3492e-04
#
# Epoch 00120: val_loss did not improve from 0.00060
# Epoch 121/150
# 3424/3424 [==============================] - 23s 7ms/step - loss: 9.3443e-05 - val_loss: 6.3856e-04
#
# Epoch 00121: val_loss did not improve from 0.00060
# Epoch 122/150
# 3424/3424 [==============================] - 23s 7ms/step - loss: 9.0963e-05 - val_loss: 6.0189e-04
#
# Epoch 00122: val_loss did not improve from 0.00060
# Epoch 123/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 9.1361e-05 - val_loss: 6.3280e-04
#
# Epoch 00123: val_loss did not improve from 0.00060
# Epoch 124/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 9.1535e-05 - val_loss: 6.2256e-04
#
# Epoch 00124: val_loss did not improve from 0.00060
# Epoch 125/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 8.9606e-05 - val_loss: 6.2193e-04
#
# Epoch 00125: val_loss did not improve from 0.00060
# Epoch 126/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 8.9586e-05 - val_loss: 6.2817e-04
#
# Epoch 00126: val_loss did not improve from 0.00060
# Epoch 127/150
# 3424/3424 [==============================] - 23s 7ms/step - loss: 8.9771e-05 - val_loss: 6.3078e-04
#
# Epoch 00127: val_loss did not improve from 0.00060
# Epoch 128/150
# 3424/3424 [==============================] - 23s 7ms/step - loss: 9.1174e-05 - val_loss: 6.2328e-04
#
# Epoch 00128: val_loss did not improve from 0.00060
# Epoch 129/150
# 3424/3424 [==============================] - 23s 7ms/step - loss: 8.9148e-05 - val_loss: 6.1062e-04
#
# Epoch 00129: val_loss did not improve from 0.00060
# Epoch 130/150
# 3424/3424 [==============================] - 23s 7ms/step - loss: 8.9265e-05 - val_loss: 6.2075e-04
#
# Epoch 00130: val_loss did not improve from 0.00060
# Epoch 131/150
# 3424/3424 [==============================] - 23s 7ms/step - loss: 8.7088e-05 - val_loss: 6.1885e-04
#
# Epoch 00131: val_loss did not improve from 0.00060
# Epoch 132/150
# 3424/3424 [==============================] - 23s 7ms/step - loss: 8.8197e-05 - val_loss: 6.3464e-04
#
# Epoch 00132: val_loss did not improve from 0.00060
# Epoch 133/150
# 3424/3424 [==============================] - 23s 7ms/step - loss: 8.9656e-05 - val_loss: 6.4621e-04
#
# Epoch 00133: val_loss did not improve from 0.00060
# Epoch 134/150
# 3424/3424 [==============================] - 23s 7ms/step - loss: 8.7711e-05 - val_loss: 6.0995e-04
#
# Epoch 00134: val_loss did not improve from 0.00060
# Epoch 135/150
# 3424/3424 [==============================] - 23s 7ms/step - loss: 8.7944e-05 - val_loss: 6.0306e-04
#
# Epoch 00135: val_loss did not improve from 0.00060
# Epoch 136/150
# 3424/3424 [==============================] - 23s 7ms/step - loss: 8.7607e-05 - val_loss: 6.1634e-04
#
# Epoch 00136: val_loss did not improve from 0.00060
# Epoch 137/150
# 3424/3424 [==============================] - 23s 7ms/step - loss: 8.8656e-05 - val_loss: 6.1838e-04
#
# Epoch 00137: val_loss did not improve from 0.00060
# Epoch 138/150
# 3424/3424 [==============================] - 23s 7ms/step - loss: 8.9171e-05 - val_loss: 6.4160e-04
#
# Epoch 00138: val_loss did not improve from 0.00060
# Epoch 139/150
# 3424/3424 [==============================] - 23s 7ms/step - loss: 8.8210e-05 - val_loss: 6.2669e-04
#
# Epoch 00139: val_loss did not improve from 0.00060
# Epoch 140/150
# 3424/3424 [==============================] - 23s 7ms/step - loss: 8.7619e-05 - val_loss: 6.4432e-04
#
# Epoch 00140: val_loss did not improve from 0.00060
# Epoch 141/150
# 3424/3424 [==============================] - 26s 8ms/step - loss: 8.5068e-05 - val_loss: 6.3377e-04
#
# Epoch 00141: val_loss did not improve from 0.00060
# Epoch 142/150
# 3424/3424 [==============================] - 23s 7ms/step - loss: 8.6718e-05 - val_loss: 6.1323e-04
#
# Epoch 00142: val_loss did not improve from 0.00060
# Epoch 143/150
# 3424/3424 [==============================] - 22s 7ms/step - loss: 8.4886e-05 - val_loss: 6.3684e-04
#
# Epoch 00143: val_loss did not improve from 0.00060
# Epoch 144/150
# 3424/3424 [==============================] - 23s 7ms/step - loss: 9.0204e-05 - val_loss: 6.6204e-04
#
# Epoch 00144: val_loss did not improve from 0.00060
# Epoch 145/150
# 3424/3424 [==============================] - 23s 7ms/step - loss: 9.1377e-05 - val_loss: 6.5273e-04
#
# Epoch 00145: val_loss did not improve from 0.00060
# Epoch 146/150
# 3424/3424 [==============================] - 22s 7ms/step - loss: 8.8288e-05 - val_loss: 6.0794e-04
#
# Epoch 00146: val_loss did not improve from 0.00060
# Epoch 147/150
# 3424/3424 [==============================] - 23s 7ms/step - loss: 8.4641e-05 - val_loss: 6.3754e-04
#
# Epoch 00147: val_loss did not improve from 0.00060
# Epoch 148/150
# 3424/3424 [==============================] - 22s 7ms/step - loss: 8.3879e-05 - val_loss: 6.1315e-04
#
# Epoch 00148: val_loss did not improve from 0.00060
# Epoch 149/150
# 3424/3424 [==============================] - 23s 7ms/step - loss: 8.5765e-05 - val_loss: 6.4695e-04
#
# Epoch 00149: val_loss did not improve from 0.00060
# Epoch 150/150
# 3424/3424 [==============================] - 23s 7ms/step - loss: 8.4253e-05 - val_loss: 6.2518e-04
#
# Epoch 00150: val_loss did not improve from 0.00060

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# 增加了左右翻轉以後，應該可以在這個範例中看到 loss 有稍微降一點（可能因為隨機而略有不同），這裡的目的主要還是去體會對原始圖像做 augmentation 以後，也要對原始 label 做合理的調整。
